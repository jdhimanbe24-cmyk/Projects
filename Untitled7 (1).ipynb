# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cols = ['engine_id', 'cycle'] + \
       [f'op_setting_{i}' for i in range(1, 4)] + \
       [f'sensor_{i}' for i in range(1, 22)]

df_fd001 = pd.read_csv('/content/train_FD001.txt',
                       sep=r'\s+',
                       header=None)


# Drop extra columns (if present)
df_fd001 = df_fd001.iloc[:, :26]

# Assign column names
df_fd001.columns = cols

# %%
df_fd001.shape
# Out:
# (20631, 26)

# %%
df_fd001.head()
# Out:
#    engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0          1      1       -0.0007       -0.0004         100.0    518.67
# 1          1      2        0.0019       -0.0003         100.0    518.67
# 2          1      3       -0.0043        0.0003         100.0    518.67
# 3          1      4        0.0007        0.0000         100.0    518.67
# 4          1      5       -0.0019       -0.0002         100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    641.82   1589.70   1400.60     14.62  ...     521.66    2388.02
# 1    642.15   1591.82   1403.14     14.62  ...     522.28    2388.07
# 2    642.35   1587.99   1404.20     14.62  ...     522.42    2388.03
# 3    642.35   1582.79   1401.87     14.62  ...     522.86    2388.08
# 4    642.37   1582.85   1406.22     14.62  ...     522.19    2388.04
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0    8138.62     8.4195       0.03        392       2388      100.0
# 1    8131.49     8.4318       0.03        392       2388      100.0
# 2    8133.23     8.4178       0.03        390       2388      100.0
# 3    8133.83     8.3682       0.03        392       2388      100.0
# 4    8133.80     8.4294       0.03        393       2388      100.0
#
#    sensor_20  sensor_21
# 0      39.06    23.4190
# 1      39.00    23.4236
# 2      38.95    23.3442
# 3      38.88    23.3739
# 4      38.90    23.4044
#
# [5 rows x 26 columns]

# %%
df_fd001['RUL'] = df_fd001.groupby('engine_id')['cycle'].transform('max') - df_fd001['cycle']

# %%
cols = ['engine_id', 'cycle'] + \
       [f'op_setting_{i}' for i in range(1, 4)] + \
       [f'sensor_{i}' for i in range(1, 22)]

# 🔹 Load test data
df_test_fd001 = pd.read_csv('/content/test_FD001.txt',
                            sep=r'\s+',
                            header=None)

# 🔹 Drop extra columns (if present)
df_test_fd001 = df_test_fd001.iloc[:, :26]

# 🔹 Assign column names
df_test_fd001.columns = cols

# =========================
# 🔹 Load RUL files
# =========================

rul_fd001 = pd.read_csv('/content/RUL_FD001.txt',
                        sep=r'\s+',
                        header=None)

rul_fd001.columns = ['RUL']

rul_fd001['RUL'] = rul_fd001['RUL']/ 125.0
df_fd001['RUL'] = df_fd001['RUL'] / 125.0

# =========================
# 🔹 Get last cycle per engine
# =========================

max_cycle_fd001 = df_test_fd001.groupby('engine_id')['cycle'].max().reset_index()
max_cycle_fd001.columns = ['engine_id', 'max_cycle']


# =========================
# 🔹 Attach RUL values
# =========================

max_cycle_fd001['RUL'] = rul_fd001['RUL']


# =========================
# 🔹 Merge with test data
# =========================

df_test_fd001 = df_test_fd001.merge(max_cycle_fd001, on='engine_id', how='left')

# =========================
# 🔹 Compute RUL for each row
# =========================

df_test_fd001['RUL'] = df_test_fd001['RUL'] + \
                       (df_test_fd001['max_cycle'] - df_test_fd001['cycle'])

# %%
df_test_fd001.head()
# Out:
#    engine_id  cycle  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0          1      1        0.0023        0.0003         100.0    518.67
# 1          1      2       -0.0027       -0.0003         100.0    518.67
# 2          1      3        0.0003        0.0001         100.0    518.67
# 3          1      4        0.0042        0.0000         100.0    518.67
# 4          1      5        0.0014        0.0000         100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  \
# 0    643.02   1585.29   1398.21     14.62  ...     521.72    2388.03
# 1    641.71   1588.45   1395.42     14.62  ...     522.16    2388.06
# 2    642.46   1586.94   1401.34     14.62  ...     521.97    2388.03
# 3    642.44   1584.12   1406.42     14.62  ...     521.38    2388.05
# 4    642.51   1587.19   1401.92     14.62  ...     522.15    2388.03
#
#    sensor_14  sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  \
# 0    8125.55     8.4052       0.03        392       2388      100.0
# 1    8139.62     8.3803       0.03        393       2388      100.0
# 2    8130.10     8.4441       0.03        393       2388      100.0
# 3    8132.90     8.3917       0.03        391       2388      100.0
# 4    8129.54     8.4031       0.03        390       2388      100.0
#
#    sensor_20  sensor_21
# 0      38.86    23.3735
# 1      39.02    23.3916
# 2      39.08    23.4166
# 3      39.00    23.3737
# 4      38.99    23.4130
#
# [5 rows x 26 columns]

# %%
def add_features(df):
    sensor_cols = [f'sensor_{i}' for i in range(1, 22)]

    for col in sensor_cols:
        df[col + '_diff'] = df[col].diff()
        df[col + '_roll'] = df[col].rolling(5).mean()

    df.fillna(method='bfill', inplace=True)
    df.fillna(method='ffill', inplace=True)

    return df

# %%
df_fd001 = add_features(df_fd001)
df_test_fd001 = add_features(df_test_fd001)
# Out:
# /tmp/ipykernel_1179/3249281948.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_1179/3249281948.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /tmp/ipykernel_1179/3249281948.py:8: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill', inplace=True)
# /tmp/ipykernel_1179/3249281948.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
# 2. define features
feature_cols = df_fd001.columns.drop(['engine_id', 'cycle', 'RUL'])

# 3. scaler
scaler = StandardScaler()

# 4. fit transform train
df_fd001[feature_cols] = scaler.fit_transform(df_fd001[feature_cols])

# 5. transform test
df_test_fd001[feature_cols] = scaler.transform(df_test_fd001[feature_cols])

# %%
def create_sequences(df, seq_length, feature_cols, stride=1):
    X, y = [], []

    for engine_id in df['engine_id'].unique():
        engine_data = df[df['engine_id'] == engine_id].sort_values('cycle')

        values = engine_data[feature_cols].values
        rul = engine_data['RUL'].values

        if len(engine_data) < seq_length:
            continue

        for i in range(0, len(engine_data) - seq_length, stride):
            X.append(values[i:i + seq_length])
            y.append(rul[i + seq_length - 1])  # FIXED alignment

    return np.array(X), np.array(y)

# %%
seq_length = 40

# %%
X_train, y_train = create_sequences(df_fd001, seq_length, feature_cols)

X_test_001, y_test_001 = create_sequences(df_test_fd001, seq_length, feature_cols)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (8341, 40, 66)
# (8341,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

model = Sequential()

model.add(LSTM(64, return_sequences=True, input_shape=(seq_length, X_train.shape[2])))
model.add(Dropout(0.3))

model.add(LSTM(32))
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

# %%
early_stop = EarlyStopping(
    monitor='val_mae',
    patience=5,
    restore_best_weights=True
)

lr_reduce = ReduceLROnPlateau(
    monitor='val_mae',
    factor=0.5,
    patience=5,
    min_lr=1e-6,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 26s 49ms/step - loss: 0.0774 - mae: 0.1947 - val_loss: 0.1149 - val_mae: 0.2345
# Epoch 2/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 27s 64ms/step - loss: 0.0347 - mae: 0.1309 - val_loss: 0.1274 - val_mae: 0.2384
# Epoch 3/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - loss: 0.0184 - mae: 0.0997 - val_loss: 0.1267 - val_mae: 0.2468
# Epoch 4/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - loss: 0.0119 - mae: 0.0806 - val_loss: 0.1395 - val_mae: 0.2533
# Epoch 5/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - loss: 0.0083 - mae: 0.0682 - val_loss: 0.1547 - val_mae: 0.2620
# Epoch 6/50
# 416/416 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - loss: 0.0062 - mae: 0.0596 - val_loss: 0.1456 - val_mae: 0.2604
